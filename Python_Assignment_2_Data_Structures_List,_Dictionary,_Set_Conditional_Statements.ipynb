# %%
###Python Assignment 2: Data Structures - List, Dictionary, Set& Conditional Statements
##1. List Creation:
##a. Create a list named age_list with five integer elements. For eg., [24, 25, 26, 27, 28]

age_list = [24,25,26,27,28]

##b. Create a list named name_list with five string elements.

name_list=["Anu", "Priya", "Kavya", "Divya", "Meena"]

# %%
##2. List Operations / Modifications:
##a. Append the string "Yazhini" to name_list.
name_list.append("Yazhini")
print("After append:", name_list)

##b. Insert the element 30 at index 2 in age_list.
age_list.insert(2,30)
print("After insert",age_list)

##c. Remove the string "Yazhini" from name_list.
name_list.remove("Yazhini")
print("After removed",name_list)

##d. Pop the last element from age_list.
age_list.pop()
print("Pop last element",age_list)

##e. Extend the age_list with additional ages [29, 30, 26].
age_list.extend([29,30,26])
print("After adding additional ages ",age_list)

##f. Sort age_list in descending order.
age_list.sort(reverse=True)
print("decending order",age_list)

##g. Find Max age, Min age and sum of all ages from age_list.
print("Max age", max(age_list))
print("Min age", min(age_list))
print("Sum of ages", sum(age_list))
# Out:
# After append: ['Anu', 'Priya', 'Kavya', 'Divya', 'Meena', 'Yazhini']
# After insert [24, 25, 30, 26, 27, 28]
# After removed ['Anu', 'Priya', 'Kavya', 'Divya', 'Meena']
# Pop last element [24, 25, 30, 26, 27]
# After adding additional ages  [24, 25, 30, 26, 27, 29, 30, 26]
# decending order [30, 30, 29, 27, 26, 26, 25, 24]
# Max age 30
# Min age 24
# Sum of ages 217

# %%
##3. Accessing List Elements:
##a. Print the first element of name_list.
print("first element",name_list[0])

##b. Print the last element of name_list.
print("Last element",name_list[4])

##c. Print the elements from index 2 to index 4 in name_list.
print("2 to 4th element",name_list[2:5])

##d. Print the elements of name_list in reverse order.
print(name_list[::-1])
# Out:
# first element Anu
# Last element Meena
# 2 to 4th element ['Kavya', 'Divya', 'Meena']
# ['Meena', 'Divya', 'Kavya', 'Priya', 'Anu']

# %%
##Dictionary (Creation, Modification and Access):
##a. Create a dictionary named student_marks that maps the names of five
##students to their marks (use scale of from 0 to 100).
student_marks = {
    "Anu": 75,
    "Priya": 88,
    "Kavya": 92,
    "Divya": 68,
    "Meena": 79
}
##b. Access and print the mark of a specific student, of your choice.
print("Kavya's mark:", student_marks["Kavya"])

##c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
student_marks["Janani"] = 80

##d. Update the mark of any one older student to 82.
student_marks["Anu"] = 82

##e. Use the keys(), values(), and items() methods to print all keys, values, and
##key-value pairs in the student_marks dictionary.

print("Values:", student_marks.values())
print("Items:", student_marks.items())
# Out:
# Kavya's mark: 92
# Values: dict_values([82, 88, 92, 68, 79, 80])
# Items: dict_items([('Anu', 82), ('Priya', 88), ('Kavya', 92), ('Divya', 68), ('Meena', 79), ('Janani', 80)])

# %%
##Sets (Operations):
##a. Create a set called my_set with following values:['a','e','i','o','u','a','a','i']
##Analyse the output and provide explanation for the same.

my_set = {'a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'}

print(my_set)

##b. Attempt to change the value of my_set[4] = 's'. If code throws an error, providean explanation.
try:
  my_set[4] = 's'
except TypeError as e:
   print("Error:", e)
   print("Explanation: Sets are unordered and do not support indexing or item assignment.")


##c. Create two sets:

#set1 with values: {1, 3, 5, 7, 9}
#set2 with values: {2, 3, 5, 8, 10}
set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}

#d. Compute and print the union and intersection of set1 and set2.
union_set = set1.union(set2)
intersection_set = set1.intersection(set2)
print("Union:", union_set)
print("Intersection:", intersection_set)
# Out:
# {'a', 'e', 'o', 'i', 'u'}
# Error: 'set' object does not support item assignment
# Explanation: Sets are unordered and do not support indexing or item assignment.
# Union: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection: {3, 5}

# %%
#Operators & Conditional Statements :(IF, ELIF, ELSE)
#Performance Category Program:
#1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
#2. Find the performance category based on the input score using following criteria:
#a. Above Average: Score greater than 7
#b. Average: Score between 4 and 7(both inclusive)
#c. Below Average: Score lesser than 4
#3. Output: Print the Performance category
#4. Additional Step: You can give a prompt of your choice to each category.
#For eg: If score below average “Need to Improve your performance, consistent practice will lead to better results”.


score=int(input("Enter your score between 0 to 10: "))

if score < 0 or score > 10:
  print("Invalid score. Please enter a score between 0 and 10.")
elif score > 7:
  print("Perforemance Category: Above Average")
  print("Excellent performance! Keep up the good work")
elif 4 <=  score <=7:
  print("Performance Category : Average")
  print("Good effort! Keep practicing to improve further")
elif score < 4:
  print("Performance Category: Below Average")
  print("Need to Improve your performance,practice will lead to better results")
# Out:
# Enter your score between 0 to 10: 3
# Performance Category: Below Average
# Need to Improve your performance,practice will lead to better results
