# %%
          #Module -4

##Python Assignment 1 - Data Structures - Strings & Tuples

#Tasks:
#Strings (Concatenation, Slicing, and Other Methods) :
#1. String Concatenation:

#Write a Python program that takes two strings, i.e., string 1 "Hello" and string 2 “get
#name” as input from the user, and concatenates them together. Display the
#concatenated string as the output.
#Sample Output:Enter your Name: Zara
#Hello Zara
#Now, concatenate string 3, "Welcome to Python programming,” to the existing string
#and display the output string.
#Sample Output:
#Hello Zara, welcome to Python programming

string1= "Hello"
string2= input("Enter your name ")

output = string1 +" "+string2
print(output)

string3= "Welcome to Python programming"
output1= output +"," +string3
print(output1)


#2. String Slicing and Indexing:

#Write a Python program using the above concatenated string as input and perform
#the following tasks:

#a. Print the first character of the string.
string = output1
print("First Character of the string is",string [0:1])

#b. Print the last character of the string.
string = output1
print("Last Character of the string is", string[-1])

#c. Print the first 5 characters of the string.
string = output1
print("First 5 character:", string[0:5])

#d. Print the last 11 characters of the string.
string = output1
print("last 11 character:", string[-11:])

#e. Print the string in reverse.
string = output1
print("Reverse:", string[::-1])


#f. Use slicing and print the word “Python” from the existing string.
string = output1
print("Python:", string[22:28])

#3. String Methods:
#Write a Python program that takes a string, strM = “Python beginner tutorial," and
#performs the following tasks:

#a. Convert the sentence to uppercase.
string=output1
print(string.upper())

#b. Convert the sentence to lowercase.
string=output1
print(string.lower())

#c. Use Capitalize and return the sentence to the original input form.
string=output1
print(string.title())

#d. Count the total number of occurrences of character ‘t’ in the string.
string=output1
print(string.count("t"))

#e. Replace all occurrences of “Python” with “Data Analytics” in the input string
#strM = “Python beginner tutorial.”
string=output1

string = string.replace("Python", "Data Analytics")

print(string)


#Tuples (Creation, Modification and Access) :
#Create the 1st tuple with values -> (10, 20, 30) and the 2nd tuple with values -> (40, 50, 60):

#a. Concatenate the two tuples and store it in “t_combine”
t1 = (10, 20, 30)
t2 = (40, 50, 60)
t_combine = t1 + t2
print("Combined tuple:", t_combine)

#b. Repeat the elements of “t_combine” 3 times
t_repeat = t_combine * 3
print("Repeated tuple:", t_repeat)

#c. Access the 3rd element from “t_combine”
print("3rd element:", t_combine[2])

#d. Access the first three elements from “t_combine”
print("First three elements:", t_combine[:3])

#e. Access the last three elements from “t_combine”
print("Last three elements:", t_combine[-3:])
# Out:
# Enter your name riya
# Hello riya
# Hello riya,Welcome to Python programming
# First Character of the string is H
# Last Character of the string is g
# First 5 character: Hello
# last 11 character: programming
# Reverse: gnimmargorp nohtyP ot emocleW,ayir olleH
# Python: Python
# HELLO RIYA,WELCOME TO PYTHON PROGRAMMING
# hello riya,welcome to python programming
# Hello Riya,Welcome To Python Programming
# 2
# Hello riya,Welcome to Data Analytics programming
# Combined tuple: (10, 20, 30, 40, 50, 60)
# Repeated tuple: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 3rd element: 30
# First three elements: (10, 20, 30)
# Last three elements: (40, 50, 60)
